# %% [markdown]
# ##Raw Data Ingestion on the bronze layer

# %%
#Raw Data Ingestion on the bronze layer
df = spark.read.csv('/FileStore/tables/Marvel/public_response.csv',header=True,inferSchema=True);

# %% [markdown]
# ##Writing Delta Format Bronze Layer

# %%
df.write.format("delta").mode("overwrite").save("/FileStore/tables/Marvel/Bronze/public_response")
