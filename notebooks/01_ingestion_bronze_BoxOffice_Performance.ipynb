# %%
dbutils.fs.ls('/FileStore/tables/Marvel/Bronze')

# %% [markdown]
# ##Raw Data Ingestion on the bronze layer

# %%
#Raw Data Ingestion on the bronze layer
df_boxoffice = spark.read.csv('/FileStore/tables/Marvel/BoxOffice_Performance.csv',header=True,inferSchema=True);

# %%
#checking schemas
df_boxoffice.printSchema()
display(df_boxoffice)

# %% [markdown]
# ##Writing Delta Format Bronze Layer

# %%
df_boxoffice.write.format("delta").mode("overwrite").save("/FileStore/tables/Marvel/Bronze/BoxOffice_Performance")
